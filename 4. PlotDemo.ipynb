# %%
using DataFrames
using RDatasets
using Gadfly
#import PyPlot

# %%
Gadfly.set_default_plot_size(5inch,5inch/golden);

# %%
?golden
# Out:
# φ = 1.6180339887498... is of type
# INFO: Loading help data...
# DataType   :
# MathConst{:φ} (constructor with 1 method)
#   supertype: Real

# %%
Gadfly.plot(dataset("datasets","iris"),x="SepalLength",y="PetalWidth",color="Species")
# Out:
# Plot(...)

# %%
Gadfly.plot(dataset("datasets","airquality"),x="Temp",y="Ozone",color="Month")
# Out:
# `convert` has no method matching convert(::Type{Float64}, ::NAtype)
#
#  in absolute_position_cy at /Users/ppalmes/.julia/v0.3/Compose/src/measure.jl:789
#  in absolute_units at /Users/ppalmes/.julia/v0.3/Compose/src/measure.jl:849
#  in draw at /Users/ppalmes/.julia/v0.3/Compose/src/form.jl:23
#  in drawpart at /Users/ppalmes/.julia/v0.3/Compose/src/container.jl:499
#  in draw at /Users/ppalmes/.julia/v0.3/Compose/src/container.jl:394
#  in writemime at /Users/ppalmes/.julia/v0.3/Gadfly/src/Gadfly.jl:802
#  in sprint at iostream.jl:229
#  in display_dict at /Users/ppalmes/.julia/v0.3/IJulia/src/execute_request.jl:31

# %%
Gadfly.plot(x=[1:1000],y=cumsum(randn(1000)),Geom.line,Guide.XLabel("time"),Guide.YLabel("random walk"))
# Out:
# Plot(...)

# %%
using Gaston

# %%
set
# Out:
# set not defined
# while loading In[5], in expression starting on line 1

# %%
gaston_demo()

# %%
x=linspace(-2pi,2pi,1000)
Gaston.plot(sin(x))
# Out:
# 20

# %%
using Winston

# %%
x=linspace(-2pi,2pi,1000)
Winston.plot(sin(x))
# Out:
# FramedPlot(...)

# %%
x=rand(10);y=rand(10);

# %%
Winston.plot(x)
# Out:
# FramedPlot(...)

# %%
Winston.plot(rand(10,2),"r+-*")
# Out:
# FramedPlot(...)

# %%
imagesc(rand(10,10))
# Out:
# FramedPlot(...)

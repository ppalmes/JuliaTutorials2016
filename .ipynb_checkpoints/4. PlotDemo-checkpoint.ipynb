# %%
using DataFrames
using RDatasets
using Gadfly
#import PyPlot
# Out:
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/StatsFuns.ji for module StatsFuns.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/DataFrames.ji for module DataFrames.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/StatsBase.ji for module StatsBase.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/ArrayViews.ji for module ArrayViews.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/DataArrays.ji for module DataArrays.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/GZip.ji for module GZip.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/SortingAlgorithms.ji for module SortingAlgorithms.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Docile.ji for module Docile.
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /Users/ppalmes/.julia/v0.4/RDatasets/src/dataset.jl:1
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /Users/ppalmes/.julia/v0.4/RDatasets/src/dataset.jl:1
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /Users/ppalmes/.julia/v0.4/RDatasets/src/datasets.jl:1
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Gadfly.ji for module Gadfly.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Codecs.ji for module Codecs.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Colors.ji for module Colors.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/FixedPointNumbers.ji for module FixedPointNumbers.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/ColorTypes.ji for module ColorTypes.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Compose.ji for module Compose.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Iterators.ji for module Iterators.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/DataStructures.ji for module DataStructures.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Cairo.ji for module Cairo.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Graphics.ji for module Graphics.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Showoff.ji for module Showoff.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/PDMats.ji for module PDMats.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Distributions.ji for module Distributions.
# WARNING: eval from module Compose to Gadfly:
# Expr(:import, :Patchwork)::Any
#   ** incremental compilation may be broken for this module **
#
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Hexagons.ji for module Hexagons.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/ImmutableArrays.ji for module ImmutableArrays.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Contour.ji for module Contour.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Loess.ji for module Loess.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Distances.ji for module Distances.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/KernelDensity.ji for module KernelDensity.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Optim.ji for module Optim.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Calculus.ji for module Calculus.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/DualNumbers.ji for module DualNumbers.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/NaNMath.ji for module NaNMath.
# INFO: Recompiling stale cache file /Users/ppalmes/.julia/lib/v0.4/Grid.ji for module Grid.

# %%
Gadfly.set_default_plot_size(5inch,5inch/golden);

# %%
?golden
# Out:
# φ = 1.6180339887498... is of type
# INFO: Loading help data...
# DataType   : MathConst{:φ} (constructor with 1 method)
#   supertype: Real

# %%
Gadfly.plot(dataset("datasets","iris"),x="SepalLength",y="PetalWidth",color="Species")
# Out:
# Plot(...)

# %%
Gadfly.plot(x=[1:1000],y=cumsum(randn(1000)),Geom.line,Guide.XLabel("time"),Guide.YLabel("random walk"))
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# Plot(...)
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at /Applications/Julia-0.4.0.app/Contents/Resources/julia/lib/julia/sys.dylib
#  in vect at abstractarray.jl:32
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /Users/ppalmes/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /Users/ppalmes/.julia/v0.4/IJulia/src/IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[5], in expression starting on line 1

# %%
using Gaston

# %%
gaston_demo()
# Out:
# Warning: empty y range [1:1], adjusting to [0.99:1.01]

# %%
x=linspace(-2pi,2pi,1000)
Gaston.plot(sin(x))
# Out:
# 20

# %%
using Winston

# %%
x=linspace(-2pi,2pi,1000)
Winston.plot(sin(x))
# Out:
# FramedPlot(...)

# %%
x=rand(10);y=rand(10);

# %%
Winston.plot(x)
# Out:
# FramedPlot(...)

# %%
Winston.plot(rand(10,2),"r+-*")
# Out:
# FramedPlot(...)

# %%
imagesc(rand(10,10))
# Out:
# FramedPlot(...)
